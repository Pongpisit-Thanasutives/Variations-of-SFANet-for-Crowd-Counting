# %%
import torch
from models import M_SFANet_UCF_QNRF

# %%
model = M_SFANet_UCF_QNRF.Model()

# %%
model.load_state_dict(torch.load("./ucf_qnrf_weights/best_M-SFANet*_UCF_QNRF.pth", map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
torch.load("./ucf_qnrf_weights/best_M-SFANet*_UCF_QNRF.pth", map_location=torch.device('cpu'))
# Out:
# OrderedDict([('vgg.conv1_1.conv.weight',
#               tensor([[[[-5.3191e-02, -5.0057e-02, -6.6530e-02],
#                         [ 1.2443e-02,  3.9903e-02,  2.6744e-04],
#                         [ 3.1572e-02,  1.3186e-02,  1.4794e-02]],
#
#                        [[ 2.0098e-02,  5.7467e-02, -2.6389e-03],
#                         [ 1.4077e-01,  2.2432e-01,  1.3732e-01],
#                         [ 1.1757e-01,  1.9637e-01,  8.9077e-02]],
#
#                        [[-3.9360e-02,  1.6560e-02, -8.7339e-03],
#                         [ 6.1076e-02,  1.3820e-01,  5.5460e-02],
#                         [-5.9051e-04,  5.6011e-02, -3.0757e-02]]],
#
#
#                       [[[ 2.5100e-01, -2.9755e-01, -4.9011e-01],
#                         [ 4.0094e-01, -2.0723e-01, -4.8740e-01],
#                         [ 5.7104e-01,  4.1360e-01, -1.3941e-01]],
#
#                        [[ 2.8081e-01, -3.2284e-01, -4.4147e-01],
#                         [ 3.7093e-01, -2.8535e-01, -4.8935e-01],
# ...
